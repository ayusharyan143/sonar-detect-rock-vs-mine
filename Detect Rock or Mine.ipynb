# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\ayush\Desktop\ML_projects\Datasets\Copy of sonar data.csv")

# %%
df.head()
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 0  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 1  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 2  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 3  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# 4  0.3039  ...  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057  0.0027
#
#    0.0090  0.0032  R
# 0  0.0052  0.0044  R
# 1  0.0095  0.0078  R
# 2  0.0040  0.0117  R
# ...

# %%
df = pd.read_csv(r"C:\Users\ayush\Desktop\ML_projects\Datasets\Copy of sonar data.csv" , header = None)

df.sample(5)
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 107  0.0428  0.0555  0.0708  0.0618  0.1215  0.1524  0.1543  0.0391  0.0610
# 20   0.0473  0.0509  0.0819  0.1252  0.1783  0.3070  0.3008  0.2362  0.3830
# 13   0.0090  0.0062  0.0253  0.0489  0.1197  0.1589  0.1392  0.0987  0.0955
# 182  0.0095  0.0308  0.0539  0.0411  0.0613  0.1039  0.1016  0.1394  0.2592
# 123  0.0270  0.0163  0.0341  0.0247  0.0822  0.1256  0.1323  0.1584  0.2017
#
#          9   ...      51      52      53      54      55      56      57  \
# 107  0.0113  ...  0.0142  0.0179  0.0079  0.0060  0.0131  0.0089  0.0084
# 20   0.3759  ...  0.0193  0.0118  0.0064  0.0042  0.0054  0.0049  0.0082
# 13   0.1895  ...  0.0059  0.0095  0.0194  0.0080  0.0152  0.0158  0.0053
# 182  0.3745  ...  0.0181  0.0019  0.0102  0.0133  0.0040  0.0042  0.0030
# 123  0.2122  ...  0.0189  0.0204  0.0085  0.0043  0.0092  0.0138  0.0094
#
#          58      59  60
# 107  0.0113  0.0049   M
# ...

# %%
df.shape
# Out:
# (208, 61)

# %%
df.describe()
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isnull().sum()
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 56    0
# 57    0
# 58    0
# 59    0
# 60    0
# Length: 61, dtype: int64

# %%
df[60].value_counts()
# Out:
# 60
# M    111
# R     97
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test = train_test_split(
    df.drop( 60 , axis = 1 ),
    df[60] , 
    test_size = 0.1,
    random_state = 0 
)

# %%
X_train.shape , X_test.shape
# Out:
# ((187, 60), (21, 60))

# %% [markdown]
# # Logistic Regression

# %%
# model train: logistic regression () 

from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

lr.fit(X_train , y_train )
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score

# %%
X_train_prediction = lr.predict( X_train ) 

train_data_accuracy = accuracy_score( X_train_prediction , y_train )

print("Accuracy on Train data: " , train_data_accuracy*100 )
# Out:
# Accuracy on Train data:  85.02673796791443

# %%
X_test_prediction = lr.predict( X_test ) 

test_data_accuracy = accuracy_score( X_test_prediction , y_test )

print("Accuracy on Train data: " , test_data_accuracy*100 )
# Out:
# Accuracy on Train data:  85.71428571428571

# %%
# make model test with example 


# Mine data

#     0.1371, 0.1226, 0.1385, 0.1484, 0.1776, 0.1428, 0.1773, 0.2161, 0.163, 0.2067,
#     0.4257, 0.5484, 0.7131, 0.7003, 0.6777, 0.7939, 0.9382, 0.8925, 0.9146, 0.7832,
#     0.796, 0.7983, 0.7716, 0.6615, 0.486, 0.5572, 0.4697, 0.564, 0.4517, 0.3369,
#     0.2684, 0.2339, 0.3052, 0.3016, 0.2753, 0.1041, 0.1757, 0.3156, 0.3603, 0.2736,
#     0.1301, 0.2458, 0.3404, 0.1753, 0.0679, 0.1062, 0.0643, 0.0532, 0.0531, 0.0272,
#     0.0171, 0.0118, 0.0129, 0.0344, 0.0065, 0.0067, 0.0022, 0.0079, 0.0146, 0.0051

# Rock data
input_data = (0.0200, 0.0371, 0.0428, 0.0207, 0.0954, 0.0986, 0.1539, 0.1601, 0.3109, 0.2111,
              0.0027, 0.0065, 0.0159, 0.0072, 0.0167, 0.0180, 0.0084, 0.0090, 0.0032, 0.0044,
              0.0200, 0.0371, 0.0428, 0.0207, 0.0954, 0.0986, 0.1539, 0.1601, 0.3109, 0.2111,
              0.0027, 0.0065, 0.0159, 0.0072, 0.0167, 0.0180, 0.0084, 0.0090, 0.0032, 0.0044,
              0.0200, 0.0371, 0.0428, 0.0207, 0.0954, 0.0986, 0.1539, 0.1601, 0.3109, 0.2111,
              0.0027, 0.0065, 0.0159, 0.0072, 0.0167, 0.0180, 0.0084, 0.0090, 0.0032, 0.0044) 




input_data_as_numpy_array = np.asarray( input_data )

# reshape the np array as we are predicting for one instance 
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = lr.predict(input_data_reshaped)
print(prediction)

# Interpret the result
result = "The Object is a Rock" if prediction == 'R' else "The Object is a Mine"
print(result)
# Out:
# ['R']
# The Object is a Rock

# %%
import joblib
joblib.dump(lr, 'logistic_model.pkl')  # Save
model = joblib.load('logistic_model.pkl')  # Load

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_pred = lr.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[ 8  0]
#  [ 3 10]]
#               precision    recall  f1-score   support
#
#            M       0.73      1.00      0.84         8
#            R       1.00      0.77      0.87        13
#
#     accuracy                           0.86        21
#    macro avg       0.86      0.88      0.86        21
# weighted avg       0.90      0.86      0.86        21

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# y_test: true labels, y_pred: predicted labels
cm = confusion_matrix(y_test, y_pred, labels=['M','R'])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Mine', 'Rock'])

disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %%
import matplotlib.pyplot as plt

models = ['Logistic Regression', 'KNN', 'Random Forest']
train_acc = [85.7, 86.1, 100]
test_acc = [86, 81, 85.7]

x = range(len(models))

plt.figure(figsize=(8,5))
plt.plot(x, train_acc, marker='o', label='Train Accuracy')
plt.plot(x, test_acc, marker='s', label='Test Accuracy')
plt.xticks(x, models)
plt.ylabel('Accuracy (%)')
plt.title('Model Accuracy Comparison')
plt.legend()
plt.show()
